# %%
import tf_encrypted as tfe
# Out:
# ---------------------------------------------------------------------------
# SymbolAlreadyExposedError                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import tf_encrypted as tfe
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_encrypted\__init__.py:12, in <module>
#       9 from pkg_resources import DistributionNotFound
#      10 from pkg_resources import get_distribution
# ---> 12 from . import convert
#      13 from . import keras
#      14 from . import operations
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_encrypted\convert\__init__.py:2, in <module>
#       1 """The TFE Converter."""
# ----> 2 from .convert import Converter
#       4 __all__ = ["Converter"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_encrypted\convert\convert.py:13, in <module>
#      11 import numpy as np
#      12 import onnx
# ---> 13 import tensorflow as tf
#      14 import tf2onnx
# ...
